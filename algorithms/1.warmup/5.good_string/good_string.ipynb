# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("good_string_input_2.txt", encoding="utf-8") as src:
    n = int(src.readline())
    qty = list(map(int, src.readlines()))

answer = 0
for idx in range(n - 1):
    if qty[idx] <= qty[idx + 1]:
        answer += qty[idx]
    else:
         answer += qty[idx + 1]
print(answer)
# Out:
# 3
