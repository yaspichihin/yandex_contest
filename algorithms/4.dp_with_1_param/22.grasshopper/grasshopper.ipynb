# %% [markdown]
# ![image.png](attachment:image.png)

# %%
filename = "grasshopper_input_1.txt"

with open(filename, encoding="utf-8") as src:
    n, k = list(map(int, src.readline().split()))

n = 1
k = 1

base = [0] * (k - 1)
base.append(1)

num = 1
for i in range(k, n + k - 1):
    num = sum(base[i - k: i])
    base.append(num)
print(num)
# Out:
# 1
