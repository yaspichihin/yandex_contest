# %% [markdown]
# ![image.png](attachment:image.png)

# %%
filename = "cafe_input_1.txt"

with open(filename, encoding="utf-8") as src:
    n = int(src.readline())
    costs = [int(cost) for cost in src.readlines()]

class Day:
    def __init__(self, cost=0, coupons=0):
        self.cost = cost
        self.coupons = coupons

    def __repr__(self):
        return f"{self.cost} {self.coupons}"


# Подготовим динамику
dp = [[float("inf") for _ in range(n+2)] for _ in range(n+1)]
dp[0][1] = Day(0, 0)

for i in range(1, n+1):
    for j in range(1, n+1):
        if dp[i-1][j].__class__.__name__ == "Day":
            value1_cost = dp[i-1][j].cost + costs[i-1]
            value1_coup = dp[i-1][j].coupons
        if dp[i-1][j-1].__class__.__name__ == "Day" and i > 2 and costs[i-2] > 100:
            value2_ = dp[i-1][j-1].cost + costs[i-1]
            value2_coup = dp[i-1][j].coupons
        



dp
# Out:
# [[inf, 0 0, inf, inf, inf, inf, inf],
#  [inf, inf, inf, inf, inf, inf, inf],
#  [inf, inf, inf, inf, inf, inf, inf],
#  [inf, inf, inf, inf, inf, inf, inf],
#  [inf, inf, inf, inf, inf, inf, inf],
#  [inf, inf, inf, inf, inf, inf, inf]]
