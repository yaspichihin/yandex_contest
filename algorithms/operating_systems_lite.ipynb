# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
filename = './operating_systems_lite_input_1.txt'

with open(filename, encoding='utf-8') as src:
    m = int(src.readline())
    n = int(src.readline())
    sectors = [line.split() for line in src.readlines()]

sectors
# Out:
# [['1', '3'], ['4', '7'], ['3', '4']]

# %%
# answer 1
# 1

#answer 2
# 3
