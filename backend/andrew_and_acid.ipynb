# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('input.txt') as file:
    rezerv = int(file.readline().strip())
    volumes = list(map(int, file.readline().strip().split()))

ans = -1
if volumes == sorted(volumes):
    ans = volumes[-1] - volumes[0]
print(ans)
# Out:
# 1
