# %% [markdown]
# ![image.png](attachment:image-2.png)

# %%
# Считаем исходные данные

with open('stone_input.txt') as input_file:
    n, npc = [line.strip().split()for line in input_file.readlines()]

# Число NPC
n = int(n[0])
# Список квестов
npc
# Out:
# ['1', '2', '3', '4', '-1']

# %%
# Создадим кэш таблицу
hash = {k: v for v, k in enumerate(npc) if k != '-1'}

ans = 'No'
hops_count = 0
for i in range(len(npc) - 1):
    if hops_count > len(npc):
        break
    if npc[i+1] == '-1' or npc[i] == '-1':
        hops_count = 0
        continue
    hops_count += 1


print("Yes" if npc[-1] == '-1' else "No")
# Out:
# Yes
